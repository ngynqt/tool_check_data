# %%
import pandas as pd 
import numpy as np

data = pd.read_csv('/home/tuong/Job/data /processed /cleaned_dataset_ver2.csv')
small_data = data.sample(frac=0.01, random_state=42)
small_data.to_csv('/home/tuong/Job/data /tmp/sampled_dataset.csv', index=False)
small_data.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 37 entries, 2144 to 2228
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Tên KH    37 non-null     str
#  1   Facebook  37 non-null     str
#  2   SĐT       37 non-null     int64
#  3   SĐT 2     1 non-null      float64
# dtypes: float64(1), int64(1), str(2)
# memory usage: 1.4 KB
